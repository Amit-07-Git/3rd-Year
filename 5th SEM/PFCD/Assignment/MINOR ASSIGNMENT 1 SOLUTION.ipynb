# %%
'''
1. c.Python variables do not need to be declared before use.
2. b.variable_1
3. # Single Line Comment
   """ For Multi
       Line Comment """
4. input()
	Takes input from the user as a string.
   print()
	Displays output on the screen.
5. c. int(’123’)
6. a. = and ==
	= is assignment operator
	== is comparison operator
   b. / and %
	/ gives floating-point division result.
	% gives the remainder of division.
   c. / and //
	/ gives floating-point division.
	// gives floor division (integer quotient).
   d. * and **
	* is multiplication.
	** is exponentiation (power).
'''

# %%
#Q7
a = int(input("Enter a:"))
a=20
b=10
print(a+b)
# Out:
# 30

# %%
#Q8
a ="nana"
b =8
c =a*b
print(c, "Batman")
# Out:
# nananananananananananananananana Batman

# %%
#Q9
print("Hi! We are studying \"Python\". \\n I hope you all are doing well.\nWeare going to have a great time!")
# Out:
# Hi! We are studying "Python". \n I hope you all are doing well.
# Weare going to have a great time!

# %%
#10
print("Amit Kumar")
print("203, Z1 Nirvaana")
print("Bhubaneswar, Odisha - 751001")
print("India")

# %%
#Q11
def evaluate(x):
    p = x**3 + 2*x**2 + 3*x + 4
    print(p)
evaluate(2)
# Out:
# 26

# %%
#Q12
import math
r = int(input("Enter the radius:"))
area = math.pi*r*r
print("The area of a circle is",area)
volume = (4/3)*math.pi*r*r*r
print("The volume of a sphere is",volume)
# Out:
# The area of a circle is 314.1592653589793
# The volume of a sphere is 4188.790204786391

# %%
#Q13
n = int(input("Enter a number to find the sum : "))
sum = (n*(n+1))/2
print("The sum of the first",n,"positive integers is:",sum)
# Out:
# The sum of the first 10 positive integers is: 55.0

# %%
#Q14
def evaluate(a,b,c):
    return (a<b) or (not(c==b) and (c<a))
print(evaluate(10,5,0))
print(evaluate(1.21,1.20,1.22))
# a =10; b=5; c=0
# print((a<b) or (not(c==b) and (c<a)))
# a=1.21; b=1.20; c=1.22
# print((a<b) or (not(c==b) and (c<a)))
# Out:
# True
# False

# %%
#Q15
def amount(n):
    a = 1000*((1+0.12)**n)
    return a
print("Amount after 10 years",amount(10))
print("Amount after 20 years",amount(20))
print("Amount after 30 years",amount(30))
# Out:
# Amount after 10 years 3105.8482083442123
# Amount after 20 years 9646.293093274951
# Amount after 30 years 29959.92212091116

# %%
#Q16
import math
x = math.e**math.pi
y = math.pi**math.e
print("e**pi :",x)
print("pi**e :",y)
if(x>y):
    print("ok")
else:
    print("ok anyway")
# Out:
# e**pi : 23.140692632779263
# pi**e : 22.45915771836104
# ok

# %%
#Q17
print("-7*20+8/16*2+54 :",-7*20+8/16*2+54)
print("7**2//9%3 :",7**2//9%3)
print("(7-4*2)*10-25*8//5 :",(7-4*2)*10-25*8//5)
print("5%10+10-25*8//5 :",5%10+10-25*8//5)
# Out:
# -7*20+8/16*2+54 : -85.0
# 7**2//9%3 : 2
# (7-4*2)*10-25*8//5 : -50
# 5%10+10-25*8//5 : -25

# %%
#Q18
print("'hi' > 'hello' and 'bye' < 'Bye':",'hi' > 'hello' and 'bye' < 'Bye')
print("'hi' > 'hello' or 'bye’ < 'Bye':",'hi' > 'hello' or 'bye' < 'Bye')
print("7>8 or 5<6 and 'I am fine' > 'I am not fine' :",7>8 or 5<6 and 'I am fine' > 'I am not fine')
print("10 !=9 and 29 >= 29 :",10 !=9 and 29 >= 29)
print("10 !=9 and 29 >= 29 and 'hi' > 'hello' or 'bye' < 'Bye' and 7 <= 2.5 :",10 !=9 and 29 >= 29 and 'hi' > 'hello' or 'bye' < 'Bye' and 7 <= 2.5)
print("5%10 + 10<50 and 29>=29 :",5%10 +  10<50 and 29>=29)
print("7 ** 2<=5 // 9%3 or 'bye' < 'Bye' :",7 ** 2<=5 // 9%3 or 'bye' < 'Bye')
print("5%10 < 8 and -25 > 1*8 // 5 :",5%10 < 8 and -25 > 1*8 // 5)
print("7 ** 2 // 4 + 5 > 8 or 5!= 6 :",7 ** 2 // 4 + 5 > 8 or 5!= 6)
print("7/4 < 6 and 'I am fine' > 'I am not fine' :",7/4 < 6 and 'I am fine' > 'I am not fine')
print("10 + 6 * 2**2 != 9//4 -3 and 29 >= 29/9 :",10 + 6 * 2**2 != 9//4 -3 and 29 >= 29/9)
print("'hello' * 5 > 'hello' or 'bye' < 'Bye' :",'hello' * 5 > 'hello' or 'bye' < 'Bye')
# Out:
# 'hi' > 'hello' and 'bye' < 'Bye': False
# 'hi' > 'hello' or 'bye’ < 'Bye': True
# 7>8 or 5<6 and 'I am fine' > 'I am not fine' : False
# 10 !=9 and 29 >= 29 : True
# 10 !=9 and 29 >= 29 and 'hi' > 'hello' or 'bye' < 'Bye' and 7 <= 2.5 : True
# 5%10 + 10<50 and 29>=29 : True
# 7 ** 2<=5 // 9%3 or 'bye' < 'Bye' : False
# 5%10 < 8 and -25 > 1*8 // 5 : False
# 7 ** 2 // 4 + 5 > 8 or 5!= 6 : True
# 7/4 < 6 and 'I am fine' > 'I am not fine' : False
# 10 + 6 * 2**2 != 9//4 -3 and 29 >= 29/9 : True
# 'hello' * 5 > 'hello' or 'bye' < 'Bye' : True

# %%
#Q19
meal_cost = float(input("Enter the cost of the meal: "))
tax_rate = 0.05
tax = meal_cost * tax_rate
tip = meal_cost * 0.18
total = meal_cost + tax + tip
print("Tax amount:", tax)
print("Tip amount:", tip)
print("Total amount:", total)
# Out:
# Tax amount: 50.0
# Tip amount: 180.0
# Total amount: 1230.0

# %%
#Q20
import math
a = int(input("Enter first integer (a): "))
b = int(input("Enter second integer (b): "))
print("Sum (a + b):", a + b)
print("Difference (a - b):", a - b)
print("Product of a and b:", a * b)
print("Quotient (a / b):", a / b)
print("Remainder (a % b):", a & b)
print("log10(a):", math.log10(a))
print("a^b:", a**b)
# Out:
# Sum (a + b): 12
# Difference (a - b): -8
# Product of a and b: 20
# Quotient (a / b): 0.2
# Remainder (a % b): 2
# log10(a): 0.3010299956639812
# a^b: 1024

# %%
#Q21
vi = 0
a = 9.8
d = int(input("Enter the distance:"))
vf = ((vi**2)+2*a*d)**0.5
print("The object will hit the ground at a speed of",vf)
# Out:
# The object will hit the ground at a speed of 44.271887242357316

# %%
#Q22
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
kelvin = celsius + 273.15
print("Temperature in Fahrenheit:", fahrenheit)
print("Temperature in Kelvin:", kelvin)
# Out:
# Temperature in Fahrenheit: 80.6
# Temperature in Kelvin: 300.15

# %%
#Q23
n = int(input("Enter a number : "))
sum = 0
while(n!=0):
    rem = n%10
    sum = sum + rem
    n = n//10
print("Sum :",sum)
# Out:
# Sum : 9

# %%
#Q24
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
c = int(input("Enter another number: "))
largest = max(a,b,c)
smallest = min(a,b,c)
middle = (a+b+c) - smallest - largest
print("Numbers in sorted order: ",smallest,middle,largest)
# Out:
# Numbers in sorted order:  23 81 99

# %%
#Q25
days = int(input("Enter number of days: "))
hours = int(input("Enter number of hours: "))
mins = int(input("Enter number of minutes: "))
sec = int(input("Enter number of seconds: "))
totalsec = (days * 24 * 3600) + (hours * 3600) + (mins * 60) + sec
print("Total duration in seconds:", totalsec)
# Out:
# Total duration in seconds: 8821510
